# %% [markdown]
# # Iniciando análise

# %%
import pandas as pd

df = pd.read_csv('/home/aluno/Documentos/GitHub/DTframe/analise_de_dados/Registros Programas de Computador_IES_Nordeste - CEARÁ (CE).csv')

# Removendo duplicatas
df.drop_duplicates(inplace=True)

# Preenchendo valores não informados:
df.fillna('Não informado', inplace=True)

# Exibindo as 5 primeiras linhas para uma visão rápida:
display(df.head())

# Exibindo uma descrição resumida e estatística das colunas 
display(df.describe(include='all'))

# Exibindo uma amostra de 5 linhas aleatórias
display(df.sample(5, random_state=1))
# Out:
# /tmp/ipykernel_19469/2543755128.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Não informado' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Não informado', inplace=True)
#       UF Sigla               Pedido    Depósito  \
# 0  Ceará   UVA  BR 51 2018 051772 2  26/09/2018
# 1  Ceará   UVA  BR 51 2018 001018 0  25/06/2018
# 2  Ceará  URCA  BR 51 2022 001300 2  30/05/2022
# 3  Ceará  UECE  BR 51 2024 003584 2  30/09/2024
# 4  Ceará  UECE  BR 51 2024 003130 8  27/08/2024
#
#                                               Título    Linguagem  \
# 0               SISTEMA DO RESTAURANTE UNIVERSITÁRIO   JAVA / PHP
# 1  Sistema de Gerenciamento de Laboratórios - Blu...          PHP
# 2  SISPRAIA: Sistema Integrado para Gestão Ambien...  JAVA SCRIPT
# 3  SP2Mic: Uma ferramenta para geração de código ...  C# / OUTROS
# ...
